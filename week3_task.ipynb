# %%
import pandas as pd
df_loan = pd.read_csv("C:/Users/admin/Downloads/datasets/loan_portfolio_dataset.csv")

# %%
df_loan.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_id                800000 non-null  int64
#  1   customer_segment       800000 non-null  str
#  2   sanction_amount        800000 non-null  int64
#  3   outstanding_principal  800000 non-null  int64
#  4   interest_rate          800000 non-null  float64
#  5   repricing_frequency    800000 non-null  str
#  6   prepayment_option      800000 non-null  str
#  7   collateral_type        800000 non-null  str
#  8   region                 800000 non-null  str
#  9   tenure_months          800000 non-null  int64
# dtypes: float64(1), int64(4), str(5)
# memory usage: 84.3 MB

# %%
df_loan.repricing_frequency
# Out:
# 0             Monthly
# 1         Half-Yearly
# 2           Quarterly
# 3         Half-Yearly
# 4             Monthly
#              ...
# 799995    Half-Yearly
# 799996      Quarterly
# 799997      Quarterly
# 799998        Monthly
# 799999    Half-Yearly
# Name: repricing_frequency, Length: 800000, dtype: str

# %%
import pandas as pd
df_borr = pd.read_csv("C:/Users/admin/Downloads/datasets/borrowing_funding_dataset.csv")

# %%
df_borr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   borrowing_id         200000 non-null  int64
#  1   funding_source       200000 non-null  str
#  2   cost_of_funds        200000 non-null  float64
#  3   maturity_bucket      200000 non-null  str
#  4   interest_reset_type  200000 non-null  str
#  5   borrowing_amount     200000 non-null  int64
#  6   rollover_risk_score  200000 non-null  float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 14.1 MB

# %%
import pandas as pd
df_cash = pd.read_csv("C:/Users/admin/Downloads/datasets/daily_cashflow_dataset.csv")

# %%
df_cash.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             300000 non-null  str
#  1   inflow_type      300000 non-null  str
#  2   outflow_type     300000 non-null  str
#  3   expected_amount  300000 non-null  int64
#  4   actual_amount    300000 non-null  int64
#  5   variance         300000 non-null  int64
# dtypes: int64(3), str(3)
# memory usage: 23.4 MB

# %%
import pandas as pd
df_macro = pd.read_csv("C:/Users/admin/Downloads/datasets/market_macro_dataset.csv")

# %%
df_macro.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             600000 non-null  str
#  1   repo_rate        600000 non-null  float64
#  2   gsec_10y         600000 non-null  float64
#  3   cp_rate          600000 non-null  float64
#  4   inflation_cpi    600000 non-null  float64
#  5   liquidity_index  600000 non-null  float64
#  6   usd_inr          600000 non-null  float64
# dtypes: float64(6), str(1)
# memory usage: 37.8 MB

# %%
df_loan["loan_inflows"] = df_loan["outstanding_principal"] * df_loan["interest_rate"]

# %%
df_loan["loan_inflows"]
# Out:
# 0         17412952.20
# 1         12860207.28
# 2         42533129.85
# 3         57385781.93
# 4         10696568.40
#              ...
# 799995    15462536.58
# 799996    43791030.90
# 799997     7484749.05
# 799998     4669542.50
# 799999    26490385.50
# Name: loan_inflows, Length: 800000, dtype: float64

# %%
df_loan['Total_loan_Inflows'] =  df_loan['loan_inflows'].sum()

# %%
df_loan['Total_loan_Inflows']
# Out:
# 0         2.003353e+13
# 1         2.003353e+13
# 2         2.003353e+13
# 3         2.003353e+13
# 4         2.003353e+13
#               ...
# 799995    2.003353e+13
# 799996    2.003353e+13
# 799997    2.003353e+13
# 799998    2.003353e+13
# 799999    2.003353e+13
# Name: Total_loan_Inflows, Length: 800000, dtype: float64

# %%
df_borr['total_borr_outflows'] = df_borr['borrowing_amount'].sum()

# %%
df_borr['total_borr_outflows']
# Out:
# 0         5093760528694
# 1         5093760528694
# 2         5093760528694
# 3         5093760528694
# 4         5093760528694
#               ...
# 199995    5093760528694
# 199996    5093760528694
# 199997    5093760528694
# 199998    5093760528694
# 199999    5093760528694
# Name: total_borr_outflows, Length: 200000, dtype: int64

# %%
net_liquidity = df_loan['Total_loan_Inflows'] - df_borr['total_borr_outflows']

# %%
net_liquidity
# Out:
# 0         1.493977e+13
# 1         1.493977e+13
# 2         1.493977e+13
# 3         1.493977e+13
# 4         1.493977e+13
#               ...
# 799995             NaN
# 799996             NaN
# 799997             NaN
# 799998             NaN
# 799999             NaN
# Length: 800000, dtype: float64

# %%
avg_cost = (df_borr['borrowing_amount'] * df_borr['cost_of_funds']).sum() / df_borr['borrowing_amount'].sum()

# %%
avg_cost
# Out:
# np.float64(8.507452044450709)

# %%
total_assets_exposure = df_loan['outstanding_principal'].sum()

# %%
total_assets_exposure
# Out:
# np.int64(1603450456828)

# %%
total_liabilities_exposure = df_borr['borrowing_amount'].sum()

# %%
total_liabilities_exposure
# Out:
# np.int64(5093760528694)

# %%
df_borr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   borrowing_id         200000 non-null  int64
#  1   funding_source       200000 non-null  str
#  2   cost_of_funds        200000 non-null  float64
#  3   maturity_bucket      200000 non-null  str
#  4   interest_reset_type  200000 non-null  str
#  5   borrowing_amount     200000 non-null  int64
#  6   rollover_risk_score  200000 non-null  float64
#  7   total_borr_outflows  200000 non-null  int64
# dtypes: float64(2), int64(3), str(3)
# memory usage: 15.6 MB

# %%
liquidity_ratio = df_loan['Total_loan_Inflows'].sum() / df_borr['total_borr_outflows'].sum()
liquidity_ratio
# Out:
# np.float64(15.731820538715608)

# %%
total_assets = df_loan['outstanding_principal'].sum()
total_liabilities = df_borr['borrowing_amount'].sum()

plt.figure()
plt.bar(['Assets', 'Liabilities'], [total_assets, total_liabilities])
plt.title("Assets vs Liabilities")
plt.ylabel("Amount")
plt.show()

# %%
funding_dist = df_borr.groupby('funding_source')['borrowing_amount'].sum()

plt.figure()
plt.pie(funding_dist, labels=funding_dist.index, autopct='%1.1f%%')
centre_circle = plt.Circle((0, 0), 0.70)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("Funding Source Distribution")
plt.show()

# %%
df_cash['cashflow_variance_trend'] = df_loan['Total_loan_Inflows'] - df_borr['total_borr_outflows']

plt.figure()
plt.plot(df_cash['date'], df_cash['cashflow_variance_trend'])
plt.title("Cashflow Variance Trend")
plt.xlabel("Date")
plt.ylabel("Variance")
plt.xticks(rotation=45)
plt.show()

# %%
net_liquidity = df_loan['Total_loan_Inflows'] - df_borr['total_borr_outflows']

plt.figure()
plt.hist(net_liquidity)
plt.title("net iquidity Distribution")
plt.xlabel("net Liquidity")
plt.ylabel("Frequency")
plt.show()

# %%
avg_cost = (df_borr['borrowing_amount'] * df_borr['cost_of_funds']).sum() / df_borr['borrowing_amount'].sum()

plt.figure()
plt.bar(['Avg Cost'], [avg_cost])
plt.title("Average Cost of Funds")
plt.show()

# %%
-----------------------------
