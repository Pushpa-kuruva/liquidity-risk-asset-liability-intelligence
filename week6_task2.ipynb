# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_final = pd.read_csv("C:/Users/admin/Downloads/datasets/final_prediction_dataset.csv")

# %%
df_final.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1000 non-null   datetime64[us]
#  1   actual_liquidity       1000 non-null   int64
#  2   loan_inflows           1000 non-null   int64
#  3   borrowing_outflows     1000 non-null   float64
#  4   repo_rate              1000 non-null   float64
#  5   cp_rate                1000 non-null   float64
#  6   liquidity_index        1000 non-null   float64
#  7   alm_gap                1000 non-null   int64
#  8   funding_risk_exposure  1000 non-null   int64
#  9   variance               1000 non-null   int64
#  10  predicted_liquidity    1000 non-null   float64
#  11  scenario               1000 non-null   str
#  12  breach_flag            1000 non-null   int64
#  13  liquidity_risk_score   1000 non-null   float64
# ...

# %%
df_final['date'] = pd.to_datetime(df_final['date'])

# %%
df_final['model_type'] = np.random.choice(
    ['Linear Regression', 'XGBoost', 'Prophet'],
    size=len(df_final)
)

# %%
df_final['model_type']
# Out:
# 0                XGBoost
# 1                XGBoost
# 2      Linear Regression
# 3                Prophet
# 4                Prophet
#              ...
# 995              XGBoost
# 996    Linear Regression
# 997    Linear Regression
# 998    Linear Regression
# 999              Prophet
# Name: model_type, Length: 1000, dtype: str

# %%
df_final['customer_segment'] = np.random.choice(
    ['Retail', 'Corporate', 'SME', 'Institutional'],
    size=len(df_final)
)

# %%
df_final['customer_segment']
# Out:
# 0      Institutional
# 1             Retail
# 2          Corporate
# 3      Institutional
# 4          Corporate
#            ...
# 995        Corporate
# 996           Retail
# 997        Corporate
# 998           Retail
# 999        Corporate
# Name: customer_segment, Length: 1000, dtype: str

# %%
df_final['funding_source'] = np.random.choice(
    ['Deposits', 'Interbank', 'Bond Market', 'Central Bank'],
    size=len(df_final))

# %%
df_final['funding_source']
# Out:
# 0         Interbank
# 1         Interbank
# 2      Central Bank
# 3         Interbank
# 4       Bond Market
#            ...
# 995        Deposits
# 996    Central Bank
# 997        Deposits
# 998        Deposits
# 999        Deposits
# Name: funding_source, Length: 1000, dtype: str

# %%
df_final['stress_level'] = np.random.choice(
    [5, 10, 15, 20, 25, 30],
    size=len(df_final)
)

# %%
df_final['stress_level']
# Out:
# 0      30
# 1       5
# 2      30
# 3      10
# 4      20
#        ..
# 995    20
# 996    20
# 997    15
# 998    10
# 999    30
# Name: stress_level, Length: 1000, dtype: int64

# %%
conditions = [
    df_final['predicted_liquidity'] < 0,
    (df_final['predicted_liquidity'] >= 0) &
    (df_final['predicted_liquidity'] < 5000),
    df_final['predicted_liquidity'] >= 5000
]

categories = ['High Risk', 'Medium Risk', 'Low Risk']

df_final['risk_category'] = np.select(
    conditions,
    categories,
    default='Medium Risk'
)

# %%
df_final['risk_category']
# Out:
# 0      High Risk
# 1      High Risk
# 2      High Risk
# 3       Low Risk
# 4      High Risk
#          ...
# 995     Low Risk
# 996    High Risk
# 997    High Risk
# 998    High Risk
# 999     Low Risk
# Name: risk_category, Length: 1000, dtype: str

# %%
df_final['time_horizon'] = np.random.choice(
    ['30 Days', '60 Days', '90 Days'],
    size=len(df_final))

# %%
df_final['time_horizon']
# Out:
# 0      60 Days
# 1      60 Days
# 2      90 Days
# 3      60 Days
# 4      60 Days
#         ...
# 995    30 Days
# 996    90 Days
# 997    30 Days
# 998    90 Days
# 999    60 Days
# Name: time_horizon, Length: 1000, dtype: str

# %%
start_date = '2025-01-01'
end_date = '2025-12-31'

filtered_df = df_final[
    (df_final['date'] >= start_date) &
    (df_final['date'] <= end_date)
]

print(filtered_df.head())
# Out:
#           date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 366 2025-01-01           2414447       1853038           3082569.0       6.83
# 367 2025-01-02           3472189        750875           1980035.0       4.67
# 368 2025-01-03           4141259        963389            688456.0       4.67
# 369 2025-01-04           3904516        570390           3153093.0       4.15
# 370 2025-01-05           1117796       1207689           2506032.0       6.95
#
#      cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 366     8.14             1.14   138882                 345300   -319118
# 367     7.22             0.84  -250532                 684010   -381304
# 368     5.02             0.57  -106584                 192036    417262
# 369     8.04             0.91   575068                 852922   -495006
# 370     5.14             0.81  -907231                 247595    290666
#
# ...

# %%
scenario_filter = 'Rate Shock'

scenario_df = df_final[
    df_final['scenario'] == scenario_filter
]

print(scenario_df.head())
# Out:
# Empty DataFrame
# Columns: [date, actual_liquidity, loan_inflows, borrowing_outflows, repo_rate, cp_rate, liquidity_index, alm_gap, funding_risk_exposure, variance, predicted_liquidity, scenario, breach_flag, liquidity_risk_score, model_type, customer_segment, funding_source, stress_level, risk_category, time_horizon]
# Index: []

# %%
model_filter = 'XGBoost'

model_df = df_final[
    df_final['model_type'] == model_filter
]

print(model_df.head())
# Out:
#          date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 0  2024-01-01           3219110       1552590           2291822.0       4.48
# 1  2024-01-02           3768307       1566646           3359653.0       4.31
# 5  2024-01-06           2692743       2303649           1530117.0       4.26
# 7  2024-01-08           1732180       2794544           2857821.0       6.16
# 10 2024-01-11           4097042        998863           1025134.0       6.50
#
#     cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 0      6.09             1.47  -333754                 458710    327675
# 1      6.65             1.11   -69630                 485893   -306016
# 5      5.73             0.73    38336                 813987    496358
# 7      7.84             1.35   168932                 592402   -246909
# 10     6.03             0.61  -659385                 360220   -393879
#
#     predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
segment_filter = 'Corporate'

segment_df = df_final[
    df_final['customer_segment'] == segment_filter
]

print(segment_df.head())
# Out:
#          date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 2  2024-01-03           3229084       2370785           2466197.0       6.79
# 4  2024-01-05           3356330       2083593           2709373.0       6.90
# 6  2024-01-07           1110268       1724665           3396818.0       5.26
# 8  2024-01-09           4200614        658823           3356376.0       7.16
# 11 2024-01-12           2570006        867654           1889959.0       7.54
#
#     cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 2      5.49             0.85  -671232                 223765   -439728
# 4      7.72             0.65  -597020                 228389    197411
# 6      7.10             0.75  -218802                 297227    238096
# 8      5.43             1.06   265804                 911804    352050
# 11     8.85             1.36   580932                 521217    -29565
#
#     predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
funding_filter = 'Deposits'

funding_df = df_final[
    df_final['funding_source'] == funding_filter
]

print(funding_df.head())
# Out:
#          date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 7  2024-01-08           1732180       2794544           2857821.0       6.16
# 11 2024-01-12           2570006        867654           1889959.0       7.54
# 12 2024-01-13           3003274       2832514            744761.0       6.46
# 14 2024-01-15           4009908       1297079           3471820.0       4.10
# 17 2024-01-18           1278167       1797286           2377109.0       7.50
#
#     cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 7      7.84             1.35   168932                 592402   -246909
# 11     8.85             1.36   580932                 521217    -29565
# 12     6.93             1.22  -358789                 396208    101160
# 14     7.20             1.21  -565624                 900554   -235763
# 17     8.81             0.96   -62365                 150081    -82433
#
#     predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
stress_filter = 20

stress_df = df_final[
    df_final['stress_level'] == stress_filter
]

print(stress_df.head())
# Out:
#          date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 4  2024-01-05           3356330       2083593           2709373.0       6.90
# 10 2024-01-11           4097042        998863           1025134.0       6.50
# 24 2024-01-25           1327069       1672622           1354016.0       5.61
# 34 2024-02-04           1989436       1474165           1916012.0       4.44
# 35 2024-02-05           2307371       1579600           2058506.0       5.42
#
#     cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 4      7.72             0.65  -597020                 228389    197411
# 10     6.03             0.61  -659385                 360220   -393879
# 24     6.64             0.91  -978719                 556285    102801
# 34     5.38             0.76  -320318                 702248   -366502
# 35     7.50             0.66    90445                 970820   -245976
#
#     predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
risk_filter = 'High Risk'

risk_df = df_final[
    df_final['risk_category'] == risk_filter
]

print(risk_df.head())
# Out:
#         date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 0 2024-01-01           3219110       1552590           2291822.0       4.48
# 1 2024-01-02           3768307       1566646           3359653.0       4.31
# 2 2024-01-03           3229084       2370785           2466197.0       6.79
# 4 2024-01-05           3356330       2083593           2709373.0       6.90
# 6 2024-01-07           1110268       1724665           3396818.0       5.26
#
#    cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 0     6.09             1.47  -333754                 458710    327675
# 1     6.65             1.11   -69630                 485893   -306016
# 2     5.49             0.85  -671232                 223765   -439728
# 4     7.72             0.65  -597020                 228389    197411
# 6     7.10             0.75  -218802                 297227    238096
#
#    predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
horizon_filter = '30 Days'

horizon_df = df_final[df_final['time_horizon'] == horizon_filter]

print(horizon_df.head())
# Out:
#          date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 5  2024-01-06           2692743       2303649           1530117.0       4.26
# 7  2024-01-08           1732180       2794544           2857821.0       6.16
# 8  2024-01-09           4200614        658823           3356376.0       7.16
# 9  2024-01-10           3234489       1941578           3437025.0       5.28
# 10 2024-01-11           4097042        998863           1025134.0       6.50
#
#     cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 5      5.73             0.73    38336                 813987    496358
# 7      7.84             1.35   168932                 592402   -246909
# 8      5.43             1.06   265804                 911804    352050
# 9      7.27             1.02  -957273                 890074   -235936
# 10     6.03             0.61  -659385                 360220   -393879
#
#     predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
horizon_filter = '60 Days'

horizon_df = df_final[ df_final['time_horizon'] == horizon_filter]

print(horizon_df.head())
# Out:
#          date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 0  2024-01-01           3219110       1552590           2291822.0       4.48
# 1  2024-01-02           3768307       1566646           3359653.0       4.31
# 3  2024-01-04           4511566       1605534            887952.0       5.36
# 4  2024-01-05           3356330       2083593           2709373.0       6.90
# 15 2024-01-16           3272355       1164076           2734693.0       7.48
#
#     cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 0      6.09             1.47  -333754                 458710    327675
# 1      6.65             1.11   -69630                 485893   -306016
# 3      5.72             0.61  -311848                 487025     -4084
# 4      7.72             0.65  -597020                 228389    197411
# 15     5.17             1.04  -988610                 168431   -224951
#
#     predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
horizon_filter = '90 Days'

horizon_df = df_final[df_final['time_horizon'] == horizon_filter]

print(horizon_df.head())
# Out:
#          date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 2  2024-01-03           3229084       2370785           2466197.0       6.79
# 6  2024-01-07           1110268       1724665           3396818.0       5.26
# 11 2024-01-12           2570006        867654           1889959.0       7.54
# 12 2024-01-13           3003274       2832514            744761.0       6.46
# 13 2024-01-14           2136074       1992785           3430098.0       4.93
#
#     cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 2      5.49             0.85  -671232                 223765   -439728
# 6      7.10             0.75  -218802                 297227    238096
# 11     8.85             1.36   580932                 521217    -29565
# 12     6.93             1.22  -358789                 396208    101160
# 13     8.22             0.57   449087                 850186    367564
#
#     predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
toggle_mode = 'Stress'

if toggle_mode == 'Normal':
    
    toggle_df = df_final[df_final['scenario'] == 'Normal']

else:
    
    toggle_df = df_final[df_final['scenario'] != 'Normal']

print(toggle_df.head())
# Out:
#           date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 500 2024-01-01           3219110       1552590           2521004.2       5.48
# 501 2024-01-02           3768307       1566646           3695618.3       5.31
# 502 2024-01-03           3229084       2370785           2712816.7       7.79
# 503 2024-01-04           4511566       1605534            976747.2       6.36
# 504 2024-01-05           3356330       2083593           2980310.3       7.90
#
#      cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 500     6.09             1.47  -333754                 458710    327675
# 501     6.65             1.11   -69630                 485893   -306016
# 502     5.49             0.85  -671232                 223765   -439728
# 503     5.72             0.61  -311848                 487025     -4084
# 504     7.72             0.65  -597020                 228389    197411
#
# ...

# %%
selected_model = 'Prophet'

selected_model_df = df_final[df_final['model_type'] == selected_model]

print(selected_model_df.head())
# Out:
#          date  actual_liquidity  loan_inflows  borrowing_outflows  repo_rate  \
# 3  2024-01-04           4511566       1605534            887952.0       5.36
# 4  2024-01-05           3356330       2083593           2709373.0       6.90
# 13 2024-01-14           2136074       1992785           3430098.0       4.93
# 16 2024-01-17           2239911       2817115           1447609.0       4.09
# 18 2024-01-19           3138242       2818136            564323.0       6.12
#
#     cp_rate  liquidity_index  alm_gap  funding_risk_exposure  variance  \
# 3      5.72             0.61  -311848                 487025     -4084
# 4      7.72             0.65  -597020                 228389    197411
# 13     8.22             0.57   449087                 850186    367564
# 16     7.53             0.58  -368960                 155745    146047
# 18     7.41             0.98   405474                 316204   -206875
#
#     predicted_liquidity scenario  breach_flag  liquidity_risk_score  \
# ...

# %%
view_mode = 'Percentage'

if view_mode == 'Absolute':
    
    df_final['display_value'] = df_final['predicted_liquidity']

else:
    
    df_final['display_value'] = (df_final['predicted_liquidity'].pct_change() ) * 100

print(df_final[['predicted_liquidity', 'display_value']].head())
# Out:
#    predicted_liquidity  display_value
# 0            -411557.0            NaN
# 1           -2099023.0     410.019997
# 2            -535140.0     -74.505282
# 3             713498.0    -233.329222
# 4            -428369.0    -160.037870
