# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '15654030',
#  'Billing Error.png',
#  'ChatGPT_INvestment.pdf',
#  'child ins.txt',
#  'desktop.ini',
#  'DL_Theory_Book.zip',
#  'Environment_Stra.pdf',
#  'GANN_RULE.png',
#  'GODZILLA.txt',
#  'Gratuity Undertaking, PF & Pension',
#  'Gratuity Undertaking, PF & Pension.zip',
#  'Huddinge, Trångsund Korpstigen 10 6\xa0731 kr-mån 5 tr 2 rum 44 kvm Anmälan senast 2024-01-18.url',
#  'lookup_json_url.json',
#  'manage.txt',
#  'Manjunath_Kuruba_Cover_Letter_Westpac.docx',
#  'Manjunath_Resume.docx',
#  'Manjunath_Resume.pdf',
#  'MEGAsync.lnk',
#  'metadata.json',
#  'Microsoft Edge.lnk',
#  'payment_method.png',
#  'Person 1 - Chrome.lnk',
#  'PolicyProposal Breakdown_Parents.pdf',
#  'Rusta och Matcha Breakdown.pdf',
#  'Ticket_Se_Amsterdam.txt',
#  'Untitled.ipynb',
#  'User account.pdf',
#  'www.cloudlogz.com.html',
#  'www.cloudlogz.com_files',
#  'Zoom.lnk',
#  'µTorrent.lnk']
